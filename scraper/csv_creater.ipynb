# %%
from helper2 import *
from os import walk

mypath = '/Users/samiramunir/Documents/Flatiron_2018/Projects/project1/scraper'

def CSVfiles():
    f = []
    for (dirpath, dirnames, filenames) in walk(mypath):
        f.extend(filenames)
        new_list = [fname.replace('.pkl', '') for fname in f if fname[-3:]=="pkl" and 'Dict' in fname]
        return new_list

# %%
csvfiles = CSVfiles()
csvfiles
# Out:
# ['glassDoorDictWashington,D.C.',
#  'glassDoorDictBoston',
#  'glassDoorDictDenver',
#  'glassDoorDictSanDiego',
#  'glassDoorDictDallas',
#  'glassDoorDictRaleigh',
#  'glassDoorDictNY',
#  'glassDoorDictPortland',
#  'glassDoorDict',
#  'glassDoorDictSt.Louis',
#  'glassDoorDictAtlanta']

# %%
for file in csvfiles: 
    build_csv_tom(file)
# Out:
# {'2967016536': ['4.3', 'data scientist', 'Red Gate Group LTD', 'Reston', 'VA', nan, nan, 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=368008&s=58&guid=0000016704fa7db2923d8eccc8d169b5&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&aa=1&ea=1&cs=1_95574aea&cb=1541976785381&jobListingId=2967016536'], '3008249706': ['3.8', 'data scientist', 'Excella Consulting', 'Washington', 'DC', 100, 151, 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=362066&s=58&guid=0000016704fa7db2923d8eccc8d169b5&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_7d18408f&cb=1541976785382&jobListingId=3008249706'], '2875917338': ['4.5', 'data scientist', 'Optoro', 'Washington', 'DC', 89, 126, 'https://www.glassdoor.com/partner/jobListing.htm?pos=103&ao=387046&s=58&guid=0000016704fa7db2923d8eccc8d169b5&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_470bc2fb&cb=1541976785383&jobListingId=2875917338'], '2972663825': ['3.8'
# ...
